# %% [markdown]
# # Clase 1 - Lun 16/3

# %% [markdown]
# # Clase XX – Título
#
# ## Objetivos
# - Punto 1
# - Punto 2
# - Punto 3
#
# ---
#
# ## 1. Concepto principal
# Texto explicativo breve.
#
# ### Ejemplo:
# ```python
# codigo_ejemplo()

# %% [markdown]
# Probando
# ```python
# #copiar ```python
# metodo()

# %% [markdown]
# ´´´python metodo()

# %% [markdown]
# hgcfhgfh
