# %% [markdown]
# <a href="https://colab.research.google.com/github/leaezequiel/python_talento_tech/blob/master/clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 1 - Lun 16/3

# %% [markdown]
# ## Introducción a Python para Análisis de Datos
#
# • Presentación del entorno de trabajo: Google Colab.
#
# • Fundamentos de Python I:
# - Tipos de datos básicos y operadores.
# - Estructuras de control: Condicionales y bucles.
# - Literal strings o f-strings.
# ---
# • Actividad: Explorar el entorno en Google Colab y escribir un primer
# script donde se declaren variables y se realicen operaciones básicas

# %% [markdown]
# ## Apuntes

# %% [markdown]
# ##Actividad

# %%
edad = 34
print(edad + 4)

#resto
print(edad/10)

#div
print(edad/2)

nombre = 'pepe'
print(f'hola mi nombre es {nombre}')

llueve = False

print(llueve == False)
# Out:
# 38
# 3.4
# 17.0
# hola mi nombre es pepe
# True
