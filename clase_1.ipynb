# %% [markdown]
# # Clase 1 - Mié 18/3

# %% [markdown]
# ## Introducción a Python para Análisis de Datos
#
# • Presentación del entorno de trabajo: Google Colab.
#
# • Fundamentos de Python I:
# - Tipos de datos básicos y operadores.
# - Estructuras de control: Condicionales y bucles.
# - Literal strings o f-strings.
# ---
# • Actividad: Explorar el entorno en Google Colab y escribir un primer
# script donde se declaren variables y se realicen operaciones básicas

# %% [markdown]
# # ACTIVIDAD EJERCICIO 1:
# Ejercicio práctico
# - Creá un nuevo bloque de texto en tu notebook de Colab.
# - Agregá un título de nivel 1 con tu nombre.
# - Escribí un breve párrafo de presentación, incluyendo formato en negrita, cursiva, y una lista con al menos 3 ítems.
# - Insertá un link externo (por ejemplo, a una página de documentación oficial de Python).
# - Desde tu Google Drive, insertá al menos una imagen relevante para tu presentación (podés ser vos, tu setup, un mapa, lo que quieras).
# - Cerrá con una cita breve o una frase que te represente usando el formato de bloque de cita (>).

# %% [markdown]
# # Leandro Ezequiel
#
# ---
#
# ## Presentación:
# Me llamo *Leandro* y el día de mañana quiero ser **quant** con la idea de:
# - ganar plata
# - aprender conocimiento
# - tener un trabajo divertido
#
# ----
#
# ## Notebook LM:
# Por eso cree este Notebook para ayudarme:
# [Notebook](https://notebooklm.google.com/notebook/61170115-e523-4378-aa2b-58b2f8fd5f3d)
#
# ---
#
# ## Atardecer inspirardor:
#
# ![Atardecer](https://drive.google.com/file/d/1C3287CZiJRGVxrzL4Vfeif1cxsvAb4RV/view?usp=sharing)
#
#
# ---
#
# ## Inspiración:
# ---
# >**"La mejor manera de predecir el futuro es crearlo".**
# ---

# %% [markdown]
# #ACTIVIDAD EJERCICIO 2:

# %% [markdown]
# 1. Insertá un nuevo bloque de código en tu notebook de Colab.
#
# 2. Escribí un programa que:
#
#   * Pida al usuario que ingrese un número entero usando input()
#
#   * Convierta ese valor a entero (int())
#
#   * Use una estructura if/else para verificar si el número es divisible por 2
#
#   * Imprima un mensaje indicando si el número es par o impar
#
# 3. Ejecutá el bloque al menos dos veces, con un número par y uno impar.

# %%
numero = int(input('ingrese numero entero'))

if numero%2 == 0:
  print('Es par')
else:
  print('es impar')
# Out:
# ingrese numero entero3
# es impar

# %% [markdown]
# ###Repaso personal:

# %%
edad = 34
print(edad + 4)

#resto
print(edad/10)

#div
print(edad/2)

nombre = 'pepe'
print(f'hola mi nombre es {nombre}')

llueve = False

print(llueve == False)
# Out:
# 38
# 3.4
# 17.0
# hola mi nombre es pepe
# True

# %% [markdown]
# ## ACTIVIDAD EJERCICIO 3:
#
# 1. Crear una lista con varios tipos de datos y acceder a sus elementos.
# 2. Crear un diccionario y acceder a sus valores por clave.

# %%
lista = ['Pinguino', 24, False, 2.0]
for elemento in lista:
  print(elemento)

persona = {
    "edad": 30,
    "club": "Boca Juniors",
    "es_daltonico": False
}
print(persona["edad"])
# Out:
# Pinguino
# 24
# False
# 2.0
# 30
